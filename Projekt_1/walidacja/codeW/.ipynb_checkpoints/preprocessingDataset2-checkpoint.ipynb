# %%
#THERE ARE TWO SEPARATE TARGET COLUMNS TO PREDICT, EITHER IN DATASET 1 AND 2

# %%
#import libraries
import numpy as np
import pandas as pd
import os

# %%
#import datasets
df1 = pd.read_csv("../data/dataset_2.csv")

# %%
# dataset 1 info
print(df1.shape)
df1.head()
# Out:
# (50000, 109)
#       var_1      var_2      var_3     var_4     var_5     var_6     var_7  \
# 0  4.532710   3.280834  17.982476  4.404259  2.349910  0.603264  2.784655
# 1  5.821374  12.098722  13.309151  4.125599  1.045386  1.832035  1.833494
# 2  1.938776   7.952752   0.972671  3.459267  1.935782  0.621463  2.338139
# 3  6.020690   9.900544  17.869637  4.366715  1.973693  2.026012  2.853025
# 4  3.909506  10.576516   0.934191  3.419572  1.871438  3.340811  1.868282
#
#       var_8      var_9     var_10  ...   var_100   var_101   var_102  \
# 0  0.323146  12.009691   0.139346  ...  2.079066  6.748819  2.941445
# 1  0.709090   8.652883   0.102757  ...  2.479789  7.795290  3.557890
# 2  0.344948   9.937850  11.691283  ...  1.861487  6.130886  3.401064
# 3  0.674847  11.816859   0.011151  ...  1.340944  7.240058  2.417235
# 4  0.439865  13.585620   1.153366  ...  2.738095  6.565509  4.341414
#
#      var_103    var_104   var_105   var_106   var_107   var_108   var_109
# 0  18.360496  17.726613  7.774031  1.473441  1.973832  0.976806  2.541417
# 1  17.383378  15.193423  8.263673  1.878108  0.567939  1.018818  1.416433
# 2  15.850471  14.620599  6.849776  1.098210  1.959183  1.575493  1.857893
# 3  15.194609  13.553772  7.229971  0.835158  2.234482  0.946170  2.700606
# 4  15.893832  11.929787  6.954033  1.853364  0.511027  2.599562  0.811364
#
# [5 rows x 109 columns]

# %%
substr = "tar"
for s in df1.columns:
    if substr in s:
        print(f"{s} contains {substr}")
# Out:
# target contains tar

# %%
# dataset 2 info
print(df1.shape)
df1.head()
# Out:
# (50000, 109)
#       var_1      var_2      var_3     var_4     var_5     var_6     var_7  \
# 0  4.532710   3.280834  17.982476  4.404259  2.349910  0.603264  2.784655
# 1  5.821374  12.098722  13.309151  4.125599  1.045386  1.832035  1.833494
# 2  1.938776   7.952752   0.972671  3.459267  1.935782  0.621463  2.338139
# 3  6.020690   9.900544  17.869637  4.366715  1.973693  2.026012  2.853025
# 4  3.909506  10.576516   0.934191  3.419572  1.871438  3.340811  1.868282
#
#       var_8      var_9     var_10  ...   var_100   var_101   var_102  \
# 0  0.323146  12.009691   0.139346  ...  2.079066  6.748819  2.941445
# 1  0.709090   8.652883   0.102757  ...  2.479789  7.795290  3.557890
# 2  0.344948   9.937850  11.691283  ...  1.861487  6.130886  3.401064
# 3  0.674847  11.816859   0.011151  ...  1.340944  7.240058  2.417235
# 4  0.439865  13.585620   1.153366  ...  2.738095  6.565509  4.341414
#
#      var_103    var_104   var_105   var_106   var_107   var_108   var_109
# 0  18.360496  17.726613  7.774031  1.473441  1.973832  0.976806  2.541417
# 1  17.383378  15.193423  8.263673  1.878108  0.567939  1.018818  1.416433
# 2  15.850471  14.620599  6.849776  1.098210  1.959183  1.575493  1.857893
# 3  15.194609  13.553772  7.229971  0.835158  2.234482  0.946170  2.700606
# 4  15.893832  11.929787  6.954033  1.853364  0.511027  2.599562  0.811364
#
# [5 rows x 109 columns]

# %%
# split merged dataset into (train/test, validate) = (80%, 20%)
df1, val1 = np.split(df1.sample(frac=1, random_state=42), [int(.8*len(df1))])

# %%
# Create a relative path to the directory you want to create
relative_path = "./validation"

# Use os.makedirs to create the directory if it does not exist
if not os.path.exists(relative_path):
    os.makedirs(relative_path)

# exporting validation dataset to csv
val1.to_csv('validation/val2.csv', encoding='utf-8')

# %%
# showing dublicate columns in data frame
from fast_ml.utilities import display_all
from fast_ml.feature_selection import get_duplicate_features

# checks weather there are duplicate columns names
duplicates = list(set([x for x in list(df1.columns) if list(df1.columns).count(x) > 1]))
print(len(duplicates))

duplicate_features = get_duplicate_features(df1)
duplicate_features.head(10)
# Out:
# 0
# Empty DataFrame
# Columns: [Desc, feature1, feature2]
# Index: []

# %%
# flaten dataframe with duplicate columns to list
duplicate_features = duplicate_features.query("Desc=='Duplicate Values'")['feature2'].to_list()
print(duplicate_features)
# Out:
# []

# %%
# drops duplicate columns and shows difference to starting df
print('Shape of Dataset before dropping the duplicate values features: ', df1.shape)
df1.drop(columns = duplicate_features, inplace=True)
print('Shape of Dataset after dropping the duplicate values features: ', df1.shape)
# Out:
# Shape of Dataset before dropping the duplicate values features:  (40000, 109)
# Shape of Dataset after dropping the duplicate values features:  (40000, 109)

# %%
from fast_ml.feature_selection import get_constant_features

constant_features = get_constant_features(df1)
constant_features.head(10)
# Out:
# Empty DataFrame
# Columns: [Desc, Var, Value, Perc]
# Index: []

# %%
print("first row data = \n", constant_features.iloc[0], "\n number of rows = \n", len(constant_features))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11888\3604342937.py in <module>
# ----> 1 print("first row data = \n", constant_features.iloc[0], "\n number of rows = \n", len(constant_features))
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1521
#    1522             # validate the location
# -> 1523             self._validate_integer(key, axis)
#    1524
#    1525             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1453         len_axis = len(self.obj._get_axis(axis))
#    1454         if key >= len_axis or key < -len_axis:
# -> 1455             raise IndexError("single positional indexer is out-of-bounds")
#    1456
#    1457     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
constant_features = constant_features.loc[(constant_features.Perc > 0.99)]
constant_features.head(10)
print(constant_features.shape)
# Out:
# (0, 4)

# %%
constant_features = constant_features["Var"].to_list()
print(constant_features)
# Out:
# []

# %%
print("Dataset shape before dropping constant and quasi constant features: ", df1.shape)
# var_109  0.195447  0.260268  0.133101  0.180533  0.168516  0.050166  1.000000
#
# [109 rows x 109 columns]

# %%
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape), k=1).astype(np.bool))
print(upper_tri)
# Out:
#          var_1     var_2     var_3     var_4     var_5     var_6     var_7  \
# var_1      NaN  0.033137  0.080228  0.019347  0.064228  0.029175  0.029823
# var_2      NaN       NaN  0.159520  0.192858  0.354650  0.335049  0.140490
# var_3      NaN       NaN       NaN  0.304661  0.019836  0.322574  0.249830
# var_4      NaN       NaN       NaN       NaN  0.112691  0.300492  0.594727
# var_5      NaN       NaN       NaN       NaN       NaN  0.186302  0.054426
# ...        ...       ...       ...       ...       ...       ...       ...
# var_105    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# var_106    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# var_107    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# var_108    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# var_109    NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#             var_8     var_9    var_10  ...   var_100   var_101   var_102  \
# var_1    0.094214  0.008060  0.090916  ...  0.228163  0.075467  0.085041
# var_2    0.144373  0.178077  0.012081  ...  0.260482  0.210277  0.121310
# var_3    0.219434  0.070160  0.282014  ...  0.349901  0.004629  0.348896
# var_4    0.127893  0.008143  0.124455  ...  0.238520  0.102002  0.468181
# var_5    0.047528  0.232153  0.080125  ...  0.207907  0.176990  0.061213
# ...           ...       ...       ...  ...       ...       ...       ...
# var_105       NaN       NaN       NaN  ...       NaN       NaN       NaN
# var_106       NaN       NaN       NaN  ...       NaN       NaN       NaN
# var_107       NaN       NaN       NaN  ...       NaN       NaN       NaN
# var_108       NaN       NaN       NaN  ...       NaN       NaN       NaN
# var_109       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#           var_103   var_104   var_105   var_106   var_107   var_108   var_109
# var_1    0.043919  0.002700  0.006724  0.204855  0.273010  0.012886  0.109990
# var_2    0.292639  0.380381  0.256796  0.161821  0.137299  0.059341  0.369822
# var_3    0.129963  0.229882  0.036641  0.226686  0.053636  0.024705  0.056155
# var_4    0.106636  0.178458  0.107362  0.324079  0.131354  0.009383  0.136265
# var_5    0.186538  0.235845  0.188462  0.128018  0.136607  0.033825  0.382788
# ...           ...       ...       ...       ...       ...       ...       ...
# var_105       NaN       NaN       NaN  0.234384  0.007541  0.022499  0.133101
# var_106       NaN       NaN       NaN       NaN  0.146028  0.015831  0.180533
# var_107       NaN       NaN       NaN       NaN       NaN  0.022487  0.168516
# var_108       NaN       NaN       NaN       NaN       NaN       NaN  0.050166
# var_109       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# [109 rows x 109 columns]
# C:\Users\Wojtek\AppData\Local\Temp\ipykernel_11888\12419535.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape), k=1).astype(np.bool))

# %%
cols_to_drop = [column for column in upper_tri.columns if any(upper_tri[column]>0.95)]
print(cols_to_drop)
# Out:
# ['var_24', 'var_28', 'var_32', 'var_39', 'var_42', 'var_43', 'var_59', 'var_72', 'var_76', 'var_80', 'var_84', 'var_94', 'var_109']

# %%
# dropping columns with high corellation
df1.drop(columns = list(cols_to_drop), axis=1, inplace=True)
print(df1.shape)
# Out:
# (40000, 96)

# %%
df1.head(10)
# Out:
#            var_1      var_2      var_3     var_4     var_5     var_6  \
# 33553   4.699999  11.533218  11.828571  3.513248  1.583830  1.624186
# 9427    4.512000   8.169495  14.890694  3.456158  1.922870  1.307190
# 199     3.113375   6.815159   6.128045  3.445057  2.027973  2.654727
# 12447   3.600000   6.423957  17.961290  4.478691  2.523918  5.758217
# 39489   3.033334  13.757996  16.673157  2.941853  1.596088  2.212440
# 42724   3.166666   9.784435  18.291429  3.320301  0.853811  1.411764
# 10822   6.175000   6.949495  13.058758  2.853788  2.086225  1.576896
# 49498   4.672973  12.122832   5.275362  3.908533  1.631330  0.714432
# 4144    4.376470   5.415085  13.679765  4.581702  1.385349  1.672546
# 36958  12.400000   7.183475  18.486487  4.558140  1.757863  1.036364
#
#           var_7         var_8      var_9    var_10  ...    var_99   var_100  \
# 33553  2.369720  1.162791e+00   7.795250  0.021805  ...  2.175823  2.387915
# 9427   2.108798  3.764699e-01   9.915947  0.025263  ...  2.014214  2.094718
# 199    1.802316  1.110910e+00  14.148850  2.747633  ...  0.670390  1.947791
# 12447  1.809964  9.579620e-01   9.895579  0.980717  ...  1.251613  1.528629
# 39489  1.987963  1.026219e+00  14.036185  0.973285  ...  0.638053  2.005737
# 42724  2.505264  1.152942e+00  11.147835  0.001715  ...  2.285715  2.004311
# 10822  2.551857  6.238270e-01   6.363293  0.245346  ...  1.736408  3.116545
# 49498  2.064425  5.999998e-01  10.578869  0.247868  ...  1.066667  3.119536
# 4144   3.307866  1.229814e+00  10.066175  0.036171  ...  1.606451  2.411495
# 36958  2.481395 -7.738972e-07   6.671045  0.001412  ...  1.621621  2.526881
#
#         var_101   var_102    var_103    var_104   var_105   var_106  \
# 33553  5.455867  2.646934  16.285621  14.963889  6.187131  1.239969
# 9427   6.249852  3.294601  16.294414  15.254241  6.165395  1.293256
# 199    8.159394  4.049460  17.045184  15.227486  7.616741  1.361353
# 12447  8.605193  4.205493  16.893393  16.910447  9.240000  1.468773
# 39489  6.417778  3.640839  18.343678  14.438780  6.627407  1.194445
# 42724  6.502255  2.922533  16.686379  14.506325  6.294738  1.245114
# 10822  4.193758  2.570239  16.044713  14.112425  4.010995  1.383359
# 49498  5.797687  2.570883  17.780995  16.764210  5.867246  0.927982
# 4144   6.414660  2.765672  17.587765  14.457270  6.034886  1.605137
# 36958  5.134884  2.799316  12.831801  12.252874  4.418604  1.325582
#
#             var_107   var_108
# 33553  2.722222e+00  2.520788
# 9427   1.187999e+00  5.574180
# 199    1.639490e+00  1.286651
# 12447  1.727273e+00  1.299782
# 39489  1.111110e+00  1.743545
# 42724  3.200000e+00  0.597375
# 10822  1.365000e+00  1.207878
# 49498  2.162163e+00  1.543983
# 4144   2.764705e+00  1.260395
# 36958  6.282009e-07  0.615535
#
# [10 rows x 96 columns]

# %%
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape), k=1).astype(np.bool))
cols_to_drop = [column for column in upper_tri.columns if any(upper_tri[column]<0.001)]
print(cols_to_drop)
# dropping columns with high corellation
df1.drop(columns = list(cols_to_drop), axis="columns", inplace=True)
print(df1.shape)

# Columns with correlation less than 0.001, would we drop this?
# Out:
# ['var_16', 'var_21', 'var_27', 'var_30', 'var_35', 'var_36', 'var_37', 'var_38', 'var_39', 'var_42', 'var_44', 'var_45', 'var_48', 'var_51', 'var_53', 'var_54', 'var_55', 'var_57', 'var_58', 'target', 'var_62', 'var_65', 'var_67', 'var_69', 'var_70', 'var_76', 'var_78', 'var_80', 'var_88', 'var_89', 'var_91', 'var_92', 'var_94', 'var_95', 'var_96', 'var_97', 'var_99', 'var_101', 'var_102', 'var_107', 'var_108', 'var_109']
# C:\Users\Wojtek\AppData\Local\Temp\ipykernel_11888\522802333.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape), k=1).astype(np.bool))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11888\522802333.py in <module>
#       3 print(cols_to_drop)
#       4 # dropping columns with high corellation
# ----> 5 df1.drop(columns = list(cols_to_drop), axis="columns", inplace=True)
#       6 print(df1.shape)
#       7
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['var_39', 'var_42', 'var_76', 'var_80', 'var_94', 'var_109'] not found in axis"

# %%
print(df1.shape)
# Out:
# (40000, 96)

# %%
cor_matrix = df1.corr().abs()

#should be graph with corellation matrix but too big data
import seaborn as sb
sb.heatmap(cor_matrix, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Description:
#  - For each column, it first computes the Z-score of each value in the column, relative to the column mean and standard deviation.
#
# - It then takes the absolute Z-score because the direction does not matter, only if it is below the threshold.
#
# - all(axis=1) ensures that for each row, all column satisfy the constraint.
#
# - Finally, the result of this condition is used to index the dataframe.

# %%
# description above
from scipy import stats

df1[(np.abs(stats.zscore(df1)) < 3).all(axis=1)]
# Out:
#           var_1      var_2      var_3     var_4     var_5     var_6     var_7  \
# 33553  4.699999  11.533218  11.828571  3.513248  1.583830  1.624186  2.369720
# 9427   4.512000   8.169495  14.890694  3.456158  1.922870  1.307190  2.108798
# 199    3.113375   6.815159   6.128045  3.445057  2.027973  2.654727  1.802316
# 4144   4.376470   5.415085  13.679765  4.581702  1.385349  1.672546  3.307866
# 1414   2.228571   5.406156  14.309054  4.228350  1.699592  1.238883  2.788162
# ...         ...        ...        ...       ...       ...       ...       ...
# 13285  5.584616   5.133566  17.674627  3.246346  1.458206  1.856501  2.246968
# 48903  5.724445   8.103664  17.524362  3.426023  1.339844  1.746535  2.588374
# 42040  4.525926   2.869500  17.695523  3.432647  1.078523  2.194194  2.162345
# 25017  5.317172   4.782543  14.349273  4.195470  2.356285  1.164706  2.524595
# 19317  3.877551   5.149755  17.500000  3.488199  1.216021  1.548655  1.926715
#
#           var_8      var_9    var_10  ...    var_99   var_100   var_101  \
# 33553  1.162791   7.795250  0.021805  ...  2.175823  2.387915  5.455867
# 9427   0.376470   9.915947  0.025263  ...  2.014214  2.094718  6.249852
# 199    1.110910  14.148850  2.747633  ...  0.670390  1.947791  8.159394
# 4144   1.229814  10.066175  0.036171  ...  1.606451  2.411495  6.414660
# 1414   0.614525  11.578616  0.062868  ...  1.320898  1.772980  7.586916
# ...         ...        ...       ...  ...       ...       ...       ...
# 13285  1.120001  11.509469  0.021015  ...  1.064180  2.360572  5.082892
# 48903  1.248514   9.356268  0.029555  ...  1.960093  2.184250  6.437516
# 42040  0.367742  13.236295  1.040410  ...  1.814925  2.093006  6.837860
# 25017  0.529411  10.401764  0.164801  ...  0.863056  2.005445  7.029664
# 19317  1.003636  12.761902  3.057679  ...  2.032979  2.140457  8.017043
#
#         var_102    var_103    var_104   var_105   var_106   var_107   var_108
# 33553  2.646934  16.285621  14.963889  6.187131  1.239969  2.722222  2.520788
# 9427   3.294601  16.294414  15.254241  6.165395  1.293256  1.187999  5.574180
# 199    4.049460  17.045184  15.227486  7.616741  1.361353  1.639490  1.286651
# 4144   2.765672  17.587765  14.457270  6.034886  1.605137  2.764705  1.260395
# 1414   2.710351  18.321729  15.958767  6.791511  1.296730  1.866072  4.353173
# ...         ...        ...        ...       ...       ...       ...       ...
# 13285  3.925708  16.930476  16.078797  4.449145  1.809097  1.928206  2.494530
# 48903  2.785575  17.796385  15.364832  5.821400  1.341084  2.802222  2.867396
# 42040  3.336031  15.958671  14.294913  7.441016  1.348148  1.814816  1.273524
# 25017  3.048957  17.175023  15.346385  6.522591  1.408947  1.690909  1.278118
# 19317  3.850532  16.730033  15.206282  8.194460  1.712826  1.319729  0.935886
#
# [22391 rows x 96 columns]

# %%
print(df1.shape)
# Out:
# (40000, 96)

# %%
# Create a relative path to the directory you want to create
relative_path = "./preprocessed"

# Use os.makedirs to create the directory if it does not exist
if not os.path.exists(relative_path):
    os.makedirs(relative_path)
# exporting preprocessed dataset to csv
df1.to_csv('preprocessed/df2.csv', encoding='utf-8')
